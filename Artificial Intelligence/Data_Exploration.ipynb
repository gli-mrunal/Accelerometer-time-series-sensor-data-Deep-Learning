# %% [markdown]
# # Data exploration

# %%
import numpy as np 
import pandas as pd 
import matplotlib as plt
import seaborn as sb

# %%
sb.set_palette("mako",3)
sb.set_style("whitegrid")

# %% [markdown]
# ## Fist Pump Motion
#
# Start by reading the first pump data and comparison plotting

# %%
fist_pump = pd.read_csv("../Training_Data/fist_pump/fist_pump000.csv")
print ('Number of samples: '+ str(len(fist_pump)))
fist_pump_pairplot = sb.pairplot(fist_pump)
# Out:
# Number of samples: 776

# %%
print(fist_pump.columns)
fist_pump.describe()
# Out:
# Index(['deltaTime', 'Acc_X', 'Acc_Y', 'Acc_Z', 'Gyro_X', 'Gyro_Y', 'Gyro_Z'], dtype='object')
#          deltaTime       Acc_X       Acc_Y       Acc_Z      Gyro_X  \
# count   776.000000  776.000000  776.000000  776.000000  776.000000
# mean   1478.496134   -0.270201    4.975628    4.206956    0.242772
# std     872.360179    6.747035    8.313215    6.331849    1.942556
# min       0.000000  -19.600000  -19.600000  -10.969000   -5.013000
# 25%     721.250000   -4.609500    1.313000   -0.835000   -0.753000
# 50%    1467.000000   -0.467000    4.012000    5.706500    0.086000
# 75%    2235.750000    4.034750   11.021000    8.983000    1.627000
# max    2998.000000   14.466000   19.596000   15.053000    4.517000
#
#            Gyro_Y      Gyro_Z
# count  776.000000  776.000000
# mean    -0.004928   -0.028629
# std      2.084349    2.605644
# min     -3.571000   -4.838000
# 25%     -1.462000   -2.004000
# 50%     -0.169500    0.213000
# 75%      0.420000    0.828000
# ...

# %% [markdown]
# To seperate the gyro and accel I create subsets based on the appropriate columns.
#
# To use seaborn to plot all x,y,z data on the same plots, I melt the data with the deltatime in all cases
#
# Relplot the data as a line

# %%
accel_fist_pump = fist_pump[['deltaTime', 'Acc_X', 'Acc_Y', 'Acc_Z']]
accel_melted_fist_pump = accel_fist_pump.melt('deltaTime',var_name='Accel''s', value_name='Meters/Sec^2')
#gyro_fist_pump = fist_pump[['deltaTime','Gyro_X', 'Gyro_Y', 'Gyro_Z']]
#gyro_melted_fist_pump = gyro_fist_pump.melt('deltaTime',var_name='Gyro''s',value_name='Rad/Sec')

# %%
fist_pump_accel = sb.relplot(x="deltaTime", y="Meters/Sec^2", hue='Accel''s', data=accel_melted_fist_pump, kind='line')
fist_pump_accel.set(ylim=(-22,22))
#fist_pump_gyro = sb.relplot(x="deltaTime", y="Rad/Sec", hue='Gyro''s', data=gyro_melted_fist_pump, kind='line')
#fist_pump_gyro.set(ylim=(-5.5,5.5))

# %% [markdown]
# ## Single Wave Motion

# %%
single_wave = pd.read_csv("../Training_Data/single_wave/single_wave000.csv")
print('Number of samples: '+ str(len(single_wave)))
single_wave_pairplot = sb.pairplot(single_wave)
# Out:
# Number of samples: 776

# %%
single_wave.describe()
# Out:
#          deltaTime       Acc_X       Acc_Y       Acc_Z      Gyro_X  \
# count   776.000000  776.000000  776.000000  776.000000  776.000000
# mean   1492.493557   -4.353630   -1.021626    4.634878    0.909164
# std     865.461463    6.522324    6.305451    3.236117    1.732040
# min       0.000000  -19.600000  -15.326000   -0.529000   -4.361000
# 25%     751.000000   -8.321000   -4.320000    2.073000   -0.093000
# 50%    1489.000000   -5.947000   -0.985000    3.786000    0.421000
# 75%    2234.000000    2.496000    0.583000    6.441000    1.856000
# max    2997.000000    6.945000   13.429000   13.758000    4.995000
#
#            Gyro_Y      Gyro_Z
# count  776.000000  776.000000
# mean     0.063671    0.217731
# std      1.872252    2.065046
# min     -4.358000   -3.659000
# 25%     -0.558250   -1.087000
# 50%     -0.004500    0.141000
# 75%      1.038500    1.192000
# max      4.212000    5.013000

# %%
accel_single_wave = single_wave[['deltaTime', 'Acc_X', 'Acc_Y', 'Acc_Z']]
accel_melted_single_wave = accel_single_wave.melt('deltaTime',var_name='Accel''s', value_name='Meters/Sec^2')
#gyro_single_wave = single_wave[['deltaTime','Gyro_X', 'Gyro_Y', 'Gyro_Z']]
#gyro_melted_single_wave = gyro_single_wave.melt('deltaTime',var_name='Gyro''s',value_name='Rad/Sec')

single_wave_accel = sb.relplot(x="deltaTime", y="Meters/Sec^2", hue='Accel''s', data=accel_melted_single_wave, kind='line')
single_wave_accel.set(ylim=(-22,22))
#single_wave_gyro = sb.relplot(x="deltaTime", y="Rad/Sec", hue='Gyro''s', data=gyro_melted_single_wave, kind='line')
#single_wave_gyro.set(ylim=(-5.5,5.5))

# %% [markdown]
# ## Random Motion

# %%
random_motion = pd.read_csv("../Training_Data/random_motion/random_motion000.csv")
print('Number of samples: '+ str(len(random_motion)))
random_motion_pairplot = sb.pairplot(random_motion)
# Out:
# Number of samples: 763

# %%
random_motion.describe()
# Out:
#          deltaTime       Acc_X       Acc_Y       Acc_Z      Gyro_X  \
# count   763.000000  763.000000  763.000000  763.000000  763.000000
# mean   1479.859764   -9.449330   -2.673982    2.204834   -0.078030
# std     873.311449    0.968928    0.968226    1.135402    1.083191
# min       0.000000  -12.835000   -4.457000    0.046000   -2.622000
# 25%     721.000000   -9.990000   -3.472500    1.496500   -1.107000
# 50%    1473.000000   -9.394000   -2.734000    2.246000    0.056000
# 75%    2237.000000   -8.821000   -2.215000    2.798000    0.618500
# max    3000.000000   -7.612000   -0.179000    6.696000    3.403000
#
#            Gyro_Y      Gyro_Z
# count  763.000000  763.000000
# mean    -0.047005   -0.012526
# std      0.306666    0.923897
# min     -0.691000   -1.785000
# 25%     -0.319000   -0.676000
# 50%     -0.035000   -0.227000
# 75%      0.164500    0.461000
# max      0.644000    2.024000

# %%
accel_random_motion = random_motion[['deltaTime', 'Acc_X', 'Acc_Y', 'Acc_Z']]
accel_melted_random_motion = accel_random_motion.melt('deltaTime',var_name='Accel''s', value_name='Meters/Sec^2')
#gyro_random_motion = random_motion[['deltaTime','Gyro_X', 'Gyro_Y', 'Gyro_Z']]
#gyro_melted_random_motion = gyro_random_motion.melt('deltaTime',var_name='Gyro''s',value_name='Rad/Sec')
print(accel_melted_random_motion)
random_motion_accel = sb.relplot(x="deltaTime", y="Meters/Sec^2", hue='Accel''s', data=accel_melted_random_motion, kind='line')
random_motion_accel.set(ylim=(-22,22))
#random_motion_gyro = sb.relplot(x="deltaTime", y="Rad/Sec", hue='Gyro''s', data=gyro_melted_random_motion, kind='line')
#random_motion_gyro.set(ylim=(-5.5,5.5))
# Out:
#       deltaTime Accels  Meters/Sec^2
# 0           0.0  Acc_X        -9.681
# 1           3.0  Acc_X        -9.706
# 2           6.0  Acc_X        -9.706
# 3           9.0  Acc_X        -9.706
# 4          12.0  Acc_X       -10.052
# ...         ...    ...           ...
# 2284     2984.0  Acc_Z         1.340
# 2285     2988.0  Acc_Z         1.340
# 2286     2992.0  Acc_Z         1.384
# 2287     2996.0  Acc_Z         1.384
# 2288     3000.0  Acc_Z         1.384
#
# [2289 rows x 3 columns]

# %% [markdown]
# ## Save all plots to files
#
# Don't forget to have all plots set to the same scale. Otherwise we cannot compare them properly
#
# I later moved them to a seperate folder

# %%
fist_pump_pairplot.savefig("fist_pump_pairplot.png")
fist_pump_accel.savefig("fist_pump_accel.png")
#fist_pump_gyro.savefig("fist_pump_gyro.png")

single_wave_pairplot.savefig("single_wave_pairplot.png")
single_wave_accel.savefig("single_wave_accel.png")
#single_wave_gyro.savefig("single_wave_gyro.png")

speed_mode_pairplot.savefig("speed_mode_pairplot.png")
speed_mode_accel.savefig("speed_mode_accel.png")
#speed_mode_gyro.savefig("speed_mode_gyro.png")

random_motion_pairplot.savefig("random_motion_pairplot.png")
random_motion_accel.savefig("random_motion_accel.png")
#random_motion_gyro.savefig("random_motion_gyro.png")

# %% [markdown]
# Lets now condense all of the data gathered so far and put it into one big csv file. Making it easier to load all the data in the other notebooks and python scripts.

# %%
import os, os.path

# %%
cd ../Training_Data
# Out:
# D:\sensors\Boxing_AI\Atltvhead-Gesture-Recognition-Bracer\Training_Data

# %%
folders = ["fist_pump","single_wave","speed_mode","random_motion"]

# %%
files =[]
completedf = pd.DataFrame(columns=['gesture','acceleration'])
for idx1,folder in enumerate(folders):
    files = os.listdir(folder)
    for idx2,file in enumerate(files):
        df_temp = pd.read_csv(folder+'/'+file)
        #print(df_temp[['Acc_X','Acc_Y','Acc_Z','Gyro_X', 'Gyro_Y', 'Gyro_Z']].to_numpy())
        x=df_temp[['Acc_X','Acc_Y','Acc_Z']].to_numpy()
        series = pd.Series(data={'gesture': folder, 'acceleration':x.tolist()})
        df_temp2= pd.DataFrame([series])
        completedf=pd.concat([completedf,df_temp2], ignore_index=True)

# %%
completedf.to_csv('complete_data.csv', index=False)

# %% [markdown]
# All the data is now condensed into the dataframe competedf. The data has also been saved to a csv file where the gesture name is given, then the

# %%
from sklearn.model_selection import train_test_split
train_ratio = 0.75
validation_ratio = 0.15
test_ratio = 0.10

# train is now 75% of the entire data set
# the _junk suffix means that we drop that variable completely
train_set, test_set = train_test_split(completedf, test_size=1 - train_ratio)

# test is now 10% of the initial data set
# validation is now 15% of the initial data set
val_set, test_set = train_test_split(test_set, test_size=test_ratio/(test_ratio + validation_ratio)) 
print('len of x_train: '+ str(len(x_train)))
print('len of x_val: '+ str(len(x_val)))
print('len of x_test: '+ str(len(x_test)))
#print(x_train, x_val, x_test)
# Out:
# len of x_train: 168
# len of x_val: 34
# len of x_test: 23
#            gesture                                       acceleration
# 13       fist_pump  [[-9.191, -0.775, 3.263], [-9.166, -0.87400000...
# 130     speed_mode  [[-3.468, -6.382000000000001, 1.875], [-3.468,...
# 110    single_wave  [[-8.315, -4.71, 6.995], [-8.315, -4.71, 6.995...
# 20       fist_pump  [[-8.517000000000001, -4.2139999999999995, 4.9...
# 222  random_motion  [[-10.033999999999999, -1.3559999999999999, 0....
# ..             ...                                                ...
# 153  random_motion  [[-7.729, -4.204, 0.867], [-7.729, -4.204, 0.8...
# 37       fist_pump  [[-8.084, -2.841, 2.9189999999999996], [-8.084...
# 209  random_motion  [[-10.382, -2.094, 3.795], [-10.382, -2.094, 3...
# 198  random_motion  [[-9.867, -0.086, 2.546], [-9.867, -0.22699999...
# 49       fist_pump  [[-8.892000000000001, -1.141, 3.034], [-8.8920...
#
# ...

# %%
print('len of x_train Speed mode: '+ str(len(train_set.query('gesture == "speed_mode"'))))
print('len of x_val Speed mode: '+ str(len(x_val.query('gesture == "speed_mode"'))))
print('len of x_test Speed mode: '+ str(len(test_set.query('gesture == "speed_mode"'))))

print('len of x_train fist_pump: '+ str(len(train_set.query('gesture == "fist_pump"'))))
print('len of x_val fist_pump: '+ str(len(x_val.query('gesture == "fist_pump"'))))
print('len of x_test fist_pump: '+ str(len(test_set.query('gesture == "fist_pump"'))))

print('len of x_train single_wave: '+ str(len(train_set.query('gesture == "single_wave"'))))
print('len of x_val single_wave: '+ str(len(x_val.query('gesture == "single_wave"'))))
print('len of x_test single_wave: '+ str(len(test_set.query('gesture == "single_wave"'))))

print('len of x_train random_motion: '+ str(len(train_set.query('gesture == "random_motion"'))))
print('len of x_val random_motion: '+ str(len(x_val.query('gesture == "random_motion"'))))
print('len of x_test random_motion: '+ str(len(test_set.query('gesture == "random_motion"'))))
# Out:
# len of x_train Speed mode: 22
# len of x_val Speed mode: 3
# len of x_test Speed mode: 1
# len of x_train fist_pump: 47
# len of x_val fist_pump: 5
# len of x_test fist_pump: 8
# len of x_train single_wave: 45
# len of x_val single_wave: 10
# len of x_test single_wave: 6
# len of x_train random_motion: 54
# len of x_val random_motion: 16
# len of x_test random_motion: 8

# %%
train_set.to_csv('train_set.csv', index=False)
test_set.to_csv('test_set.csv', index=False)
val_set.to_csv('val_set.csv', index=False)

# %% [markdown]
# Another Way of splitting without using scikit learn

# %%
completedf_copy= completedf.copy()

# %%
train_set = completedf_copy.sample(frac=0.75, random_state=4)
test_set = completedf_copy.drop(train_set.index)
val_set = test_set.sample(frac=0.6, random_state=4)
test_set = test_set.drop(val_set.index)

# %%
print(len(train_set),len(val_set),len(test_set))
# Out:
# 169 34 22

# %%
len(test_set.query('gesture == "speed_mode"'))
# Out:
# 1

# %%
print('len of x_train Speed mode: '+ str(len(train_set.query('gesture == "speed_mode"'))))
print('len of x_val Speed mode: '+ str(len(val_set.query('gesture == "speed_mode"'))))
print('len of x_test Speed mode: '+ str(len(test_set.query('gesture == "speed_mode"'))))

print('len of x_train fist_pump: '+ str(len(train_set.query('gesture == "fist_pump"'))))
print('len of x_val fist_pump: '+ str(len(val_set.query('gesture == "fist_pump"'))))
print('len of x_test fist_pump: '+ str(len(test_set.query('gesture == "fist_pump"'))))

print('len of x_train single_wave: '+ str(len(train_set.query('gesture == "single_wave"'))))
print('len of x_val single_wave: '+ str(len(val_set.query('gesture == "single_wave"'))))
print('len of x_test single_wave: '+ str(len(test_set.query('gesture == "single_wave"'))))

print('len of x_train random_motion: '+ str(len(train_set.query('gesture == "random_motion"'))))
print('len of x_val random_motion: '+ str(len(val_set.query('gesture == "random_motion"'))))
print('len of x_test random_motion: '+ str(len(test_set.query('gesture == "random_motion"'))))
# Out:
# len of x_train Speed mode: 19
# len of x_val Speed mode: 6
# len of x_test Speed mode: 1
# len of x_train fist_pump: 46
# len of x_val fist_pump: 7
# len of x_test fist_pump: 7
# len of x_train single_wave: 49
# len of x_val single_wave: 10
# len of x_test single_wave: 2
# len of x_train random_motion: 55
# len of x_val random_motion: 11
# len of x_test random_motion: 12

# %%
train_set = x_train.copy()
val_set = x_val.copy()
test_set = x_test.copy()

# %%
print('len of x_train Speed mode: '+ str(len(train_set.query('gesture == "speed_mode"'))))
print('len of x_val Speed mode: '+ str(len(val_set.query('gesture == "speed_mode"'))))
print('len of x_test Speed mode: '+ str(len(test_set.query('gesture == "speed_mode"'))))

print('len of x_train fist_pump: '+ str(len(train_set.query('gesture == "fist_pump"'))))
print('len of x_val fist_pump: '+ str(len(val_set.query('gesture == "fist_pump"'))))
print('len of x_test fist_pump: '+ str(len(test_set.query('gesture == "fist_pump"'))))

print('len of x_train single_wave: '+ str(len(train_set.query('gesture == "single_wave"'))))
print('len of x_val single_wave: '+ str(len(val_set.query('gesture == "single_wave"'))))
print('len of x_test single_wave: '+ str(len(test_set.query('gesture == "single_wave"'))))

print('len of x_train random_motion: '+ str(len(train_set.query('gesture == "random_motion"'))))
print('len of x_val random_motion: '+ str(len(val_set.query('gesture == "random_motion"'))))
print('len of x_test random_motion: '+ str(len(test_set.query('gesture == "random_motion"'))))
# Out:
# len of x_train Speed mode: 22
# len of x_val Speed mode: 3
# len of x_test Speed mode: 1
# len of x_train fist_pump: 47
# len of x_val fist_pump: 5
# len of x_test fist_pump: 8
# len of x_train single_wave: 45
# len of x_val single_wave: 10
# len of x_test single_wave: 6
# len of x_train random_motion: 54
# len of x_val random_motion: 16
# len of x_test random_motion: 8
